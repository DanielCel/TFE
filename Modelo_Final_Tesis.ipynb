# %%
# Importar las bibliotecas
import pandas as pd
from google.colab import drive
# Montar Google Drive
drive.mount('/content/drive')
# Ruta donde se guardará el archivo en Google Drive
ruta_archivo = '/content/drive/My Drive/Tesis/data/data_tesis_completa_local.xlsx'
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers datasets torch
# !pip install pytorch-tabnet
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: pytorch-tabnet in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.26.4)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.6.0)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (1.13.1)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (2.5.1+cu121)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.10/dist-packages (from pytorch-tabnet) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch-tabnet) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch-tabnet) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.3->pytorch-tabnet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->pytorch-tabnet) (3.0.2)

# %% [markdown]
# ## **PREPROCESAMIENTO DE LA DATA**

# %%
df = pd.read_excel(ruta_archivo)

# %%
estadio_alturas = {
  'Estadio Banco Guayaquil': 2518,
  'Estadio Rodrigo Paz Delgado': 2726,
  'Estadio Monumental Isidro Romero Carbo': 9,
  'Estadio Olímpico Atahualpa': 2783,
  'Estadio 9 de Mayo':5,
  'Estadio Federativo Reina del Cisne': 2072,
  'Estadio Jocay':34,
  'Estadio Olímpico de Ibarra': 2200,
  'Estadio Bellavista de Ambato': 2617,
  'Estadio Gonzalo Pozo Ripalda': 2867,
  'Estadio del Mushuc Runa Sporting Club': 3252,
  'Estadio George Capwell':3,
  'Estadio Alejandro Serrano Aguilar': 2523,
  'Estadio Municipal La Cocha': 2778,
  'Estadio Christian Benítez Betancourt':4,
  'Estadio Municipal Jorge Andrade Cantos': 2514,
  'Estadio Gerardo León Pozo': 2296,
  'Estadio Modelo Alberto Spencer':11,
  'Estadio Olímpico de Riobamba': 2771,
  'Estadio General Rumiñahui del Valle': 2500,
  'Estadio Reales Tamarindos':53
}

Equipos_sin_altura =['9 de Octubre FC',
                     'Barcelona SC',
                     'CS Emelec',
                     'Delfin SC',
                     'Fuerza Amarilla SC',
                     'Guayaquil City FC',
                     'LDU Portoviejo',
                     'Manta FC',
                     'Orense SC']

Equipos_con_altura =['CD Independiente del Valle',
                     'LDU de Quito',
                     'CD El Nacional',
                     'Libertad FC',
                     'Imbabura SC',
                     'CD Macara',
                     'SD Aucas',
                     'Mushuc Runa SC',
                     'CD Universidad Catolica',
                     'Cumbaya FC',
                     'CD Tecnico Universitario',
                     'CD Cuenca',
                     'Gualaceo SC',
                     'CD Olmedo',
                     'CD America Quito']

Altura_por_equipo = {
    '9 de Octubre FC': 11,
    'Barcelona SC': 9,
    'CD America Quito': 2783,
    'CD Cuenca':2523,
    'CD El Nacional': 2783,
    'CD Independiente del Valle': 2518,
    'CD Macara': 2617,
    'CD Olmedo': 2771,
    'CD Tecnico Universitario':2617,
    'CD Universidad Catolica': 2783,
    'CS Emelec':3,
    'Cumbaya FC':2783,
    'Delfin SC': 34,
    'Fuerza Amarilla SC': 5,
    'Gualaceo SC': 2296,
    'Guayaquil City FC':4,
    'Imbabura SC': 2200,
    'LDU de Quito': 2726,
    'LDU Portoviejo': 53,
    'Libertad FC': 2072,
    'Manta FC': 34,
    'Mushuc Runa SC': 3252,
    'Orense SC': 5,
    'SD Aucas': 2867,
}

# %%
# Reemplazo de los nombres de los estadios por sus alturas
df['Estadio'] = df['Estadio'].replace(estadio_alturas)
df = df.rename(columns={'Estadio': 'Altura'})

df['Saldo_Goles'] = df['GF'] - df['GC']
df = df.drop(['GF', 'GC'], axis=1)

# Calcular la diferencia de altitud
df['diferencia_altitud'] = df['Altura'] - df['Adversario'].map(Altura_por_equipo)

# Scalar las probabilidades
df['P. Victoria'] = 1 / df['P. Victoria'].astype(float)
df['P. Empate'] = 1 / df['P. Empate'].astype(float)
df['P. Perdida'] = 1 / df['P. Perdida'].astype(float)
# Out:
# <ipython-input-370-86aa82e6d26d>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Estadio'] = df['Estadio'].replace(estadio_alturas)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
encoder = OneHotEncoder(sparse_output=False)
prefijo_vst = 'vst_'
prefijo_lcl = 'lcl_'

# Formaciones del Oponente
formaciones_oponente_encoded = encoder.fit_transform(df[['Formación del oponente']])
formaciones_oponente_df = pd.DataFrame(formaciones_oponente_encoded, columns=[f"{prefijo_vst}{categoria}" for categoria in encoder.categories_[0]])

# Formaciones del Local
formaciones_encoded = encoder.fit_transform(df[['Formación']])
formaciones_df = pd.DataFrame(formaciones_encoded, columns=[f"{prefijo_lcl}{categoria}" for categoria in encoder.categories_[0]])

# %%
# Unir los datos preprocesados
df = pd.concat([df, formaciones_oponente_df,formaciones_df], axis=1)

# %%
def clasificar_partido(row):
    local_en_altura = row['Equipo'] in Equipos_con_altura
    visitante_en_altura = row['Adversario'] in Equipos_con_altura
    local_en_costa = row['Equipo'] in Equipos_sin_altura
    visitante_en_costa = row['Adversario'] in Equipos_sin_altura

    if local_en_altura and visitante_en_altura:
        return 'Altura vs Altura'
    elif local_en_costa and visitante_en_costa:
        return 'Costa vs Costa'
    elif local_en_altura and visitante_en_costa:
        return 'Altura vs Costa'
    elif local_en_costa and visitante_en_altura:
        return 'Costa vs Altura'

# Aplicar la función al DataFrame
df['clasificacion_del_partido'] = df.apply(clasificar_partido, axis=1)

# %%
df_sierra_costa = df[df['clasificacion_del_partido'] == 'Altura vs Costa']
df_costa_sierra = df[df['clasificacion_del_partido'] == 'Costa vs Altura']
df_sierra_sierra = df[df['clasificacion_del_partido'] == 'Altura vs Altura']
df_costa_costa = df[df['clasificacion_del_partido'] == 'Costa vs Costa']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler

# Escalar variables continuas
scaler = MinMaxScaler()
df[[ 'diferencia_altitud', 'Saldo_Goles','Altura']] = scaler.fit_transform( df[['diferencia_altitud', 'Saldo_Goles','Altura']])

# %% [markdown]
# ## **MODELO DE RED NEURONAL MLP**

# %%
data_evaluar = df.copy()

# %%
y_variables = [
    "vst_3-1-4-2",
    "vst_3-3-3-1",
    "vst_3-4-1-2",
    "vst_3-4-2-1",
    "vst_3-4-3",
    "vst_3-5-1-1",
    "vst_3-5-2",
    "vst_4-1-3-2",
    "vst_4-1-4-1",
    "vst_4-2-2-2",
    "vst_4-2-3-1",
    "vst_4-3-1-2",
    "vst_4-3-2-1",
    "vst_4-3-3",
    "vst_4-4-1-1",
    "vst_4-4-2",
    "vst_4-5-1",
    "vst_5-3-2",
    "vst_5-4-1",]
x_variables = [
    "P. Victoria",
    "P. Empate",
    "P. Perdida",
    "Saldo_Goles",
    "diferencia_altitud",
    "lcl_3-1-4-2",
    "lcl_3-2-4-1",
    "lcl_3-4-1-2",
    "lcl_3-4-3",
    "lcl_3-5-1-1",
    "lcl_3-5-2",
    "lcl_4-1-3-2",
    "lcl_4-1-4-1",
    "lcl_4-2-2-2",
    "lcl_4-2-3-1",
    "lcl_4-3-1-2",
    "lcl_4-3-2-1",
    "lcl_4-3-3",
    "lcl_4-4-1-1",
    "lcl_4-4-2",
    "lcl_4-5-1",
    "lcl_5-3-2",
    "lcl_5-4-1"
]

# %%
val_data = data_evaluar[(data_evaluar['Resultado'] == 'D') & (data_evaluar['Fecha'].dt.year == 2024) &(data_evaluar['clasificacion_del_partido'] == 'Altura vs Costa')]

# %%
test_data = data_evaluar[data_evaluar['Fecha'].dt.year == 2024]
train_data = data_evaluar[data_evaluar['Fecha'].dt.year != 2024]

# %%
# Separar características y etiquetas
X_train = train_data[x_variables]  # Características de entrenamiento
y_train = train_data[y_variables]      # Etiquetas de entrenamiento

X_test = test_data[x_variables]        # Características de validación
y_test = test_data[y_variables]          # Etiquetas de validación

# %%
import tensorflow as tf
import numpy as np

# Función de pérdida ponderada
def weighted_loss(y_true, y_pred):
    # Convertir 'y_true' a formato One-Hot
    y_true_one_hot = tf.one_hot(tf.argmax(y_true, axis=1), depth=y_pred.shape[1])

    # Obtener los índices de los datos del batch actual
    batch_indices = tf.range(tf.shape(y_true)[0])

    # Obtener los valores de 'resultado' y 'altura' para el batch actual
    resultado_batch = tf.gather(df['Resultado'].values, batch_indices)
    #altura_batch = tf.gather(df['altura'].values, batch_indices)

    # Crear pesos para la pérdida para el batch actual
    weights = tf.where(resultado_batch == 'V', 3.0,
                       tf.where(resultado_batch == 'E', 2.0,
                                1.0))

    # Calcular la pérdida ponderada
    loss = tf.reduce_mean(tf.losses.categorical_crossentropy(y_true_one_hot, y_pred) * weights)

    return loss

# %%
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
# Crear el modelo de red neuronal

model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(y_train.shape[1], activation='softmax')  # Salida con softmax para clasificación
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compilar el modelo con la función de pérdida ponderada
model.compile(optimizer='adam', loss=weighted_loss, metrics=['accuracy'])

# %%
# Entrenar el modelo
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1296 - loss: 6.5954 - val_accuracy: 0.3636 - val_loss: 5.8056
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3608 - loss: 5.4641 - val_accuracy: 0.3636 - val_loss: 4.4968
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3562 - loss: 4.5245 - val_accuracy: 0.3595 - val_loss: 4.2324
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3638 - loss: 4.3457 - val_accuracy: 0.3636 - val_loss: 4.1943
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3518 - loss: 4.3267 - val_accuracy: 0.3636 - val_loss: 4.1776
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3446 - loss: 4.3487 - val_accuracy: 0.3678 - val_loss: 4.1535
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3452 - loss: 4.3157 - val_accuracy: 0.3719 - val_loss: 4.1665
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3574 - loss: 4.3594 - val_accuracy: 0.3678 - val_loss: 4.1664
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3455 - loss: 4.2999 - val_accuracy: 0.3636 - val_loss: 4.1583
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3628 - loss: 4.1944 - val_accuracy: 0.3554 - val_loss: 4.1639
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3471 - loss: 4.1499 - val_accuracy: 0.3595 - val_loss: 4.1732
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3340 - loss: 4.4736 - val_accuracy: 0.3636 - val_loss: 4.1761
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3683 - loss: 4.2005 - val_accuracy: 0.3719 - val_loss: 4.1585
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3577 - loss: 4.1334 - val_accuracy: 0.3595 - val_loss: 4.1609
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3855 - loss: 4.1173 - val_accuracy: 0.3554 - val_loss: 4.1743
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3392 - loss: 4.2161 - val_accuracy: 0.3595 - val_loss: 4.1945
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3504 - loss: 4.2521 - val_accuracy: 0.3636 - val_loss: 4.1651
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3494 - loss: 4.2943 - val_accuracy: 0.3595 - val_loss: 4.1760
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3915 - loss: 4.0503 - val_accuracy: 0.3636 - val_loss: 4.1701
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3629 - loss: 4.2457 - val_accuracy: 0.3636 - val_loss: 4.1603
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3487 - loss: 4.3471 - val_accuracy: 0.3678 - val_loss: 4.1698
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3760 - loss: 4.0463 - val_accuracy: 0.3554 - val_loss: 4.1777
# Epoch 23/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3605 - loss: 4.1431 - val_accuracy: 0.3471 - val_loss: 4.1667
# Epoch 24/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3608 - loss: 4.2413 - val_accuracy: 0.3595 - val_loss: 4.1700
# Epoch 25/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3774 - loss: 4.1138 - val_accuracy: 0.3471 - val_loss: 4.1656
# Epoch 26/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3705 - loss: 4.1714 - val_accuracy: 0.3595 - val_loss: 4.1826
# Epoch 27/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3712 - loss: 4.2039 - val_accuracy: 0.3678 - val_loss: 4.1742
# Epoch 28/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3485 - loss: 4.2673 - val_accuracy: 0.3678 - val_loss: 4.1777
# Epoch 29/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3650 - loss: 4.0247 - val_accuracy: 0.3678 - val_loss: 4.2092
# Epoch 30/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3673 - loss: 4.1559 - val_accuracy: 0.3719 - val_loss: 4.1847
# Epoch 31/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3452 - loss: 4.1673 - val_accuracy: 0.3595 - val_loss: 4.1960
# Epoch 32/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3624 - loss: 4.1633 - val_accuracy: 0.3595 - val_loss: 4.1892
# Epoch 33/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3802 - loss: 4.0383 - val_accuracy: 0.3595 - val_loss: 4.1949
# Epoch 34/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3866 - loss: 3.9734 - val_accuracy: 0.3471 - val_loss: 4.1956
# Epoch 35/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3839 - loss: 4.0508 - val_accuracy: 0.3678 - val_loss: 4.2050
# Epoch 36/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3623 - loss: 4.1891 - val_accuracy: 0.3554 - val_loss: 4.2038
# Epoch 37/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3822 - loss: 4.2710 - val_accuracy: 0.3719 - val_loss: 4.1954
# Epoch 38/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3816 - loss: 4.0581 - val_accuracy: 0.3512 - val_loss: 4.2045
# Epoch 39/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3734 - loss: 4.1180 - val_accuracy: 0.3595 - val_loss: 4.1990
# Epoch 40/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3977 - loss: 4.1044 - val_accuracy: 0.3512 - val_loss: 4.2129
# Epoch 41/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3899 - loss: 4.0224 - val_accuracy: 0.3430 - val_loss: 4.2294
# Epoch 42/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3655 - loss: 4.1946 - val_accuracy: 0.3719 - val_loss: 4.2144
# Epoch 43/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3649 - loss: 4.2089 - val_accuracy: 0.3554 - val_loss: 4.2199
# Epoch 44/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3851 - loss: 4.2149 - val_accuracy: 0.3719 - val_loss: 4.2271
# Epoch 45/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3808 - loss: 4.1600 - val_accuracy: 0.3719 - val_loss: 4.2243
# Epoch 46/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3873 - loss: 3.9574 - val_accuracy: 0.3595 - val_loss: 4.2263
# Epoch 47/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3732 - loss: 4.0702 - val_accuracy: 0.3636 - val_loss: 4.2330
# Epoch 48/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3638 - loss: 4.1587 - val_accuracy: 0.3678 - val_loss: 4.2355
# Epoch 49/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3829 - loss: 4.0198 - val_accuracy: 0.3595 - val_loss: 4.2225
# Epoch 50/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3740 - loss: 4.0879 - val_accuracy: 0.3430 - val_loss: 4.2166
# Epoch 51/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3625 - loss: 4.1275 - val_accuracy: 0.3802 - val_loss: 4.2017
# Epoch 52/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3803 - loss: 3.9779 - val_accuracy: 0.3636 - val_loss: 4.2205
# Epoch 53/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3812 - loss: 4.0713 - val_accuracy: 0.3471 - val_loss: 4.2202
# Epoch 54/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3818 - loss: 4.0548 - val_accuracy: 0.3347 - val_loss: 4.2205
# Epoch 55/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3798 - loss: 3.9590 - val_accuracy: 0.3719 - val_loss: 4.2297
# Epoch 56/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3784 - loss: 4.0712 - val_accuracy: 0.3554 - val_loss: 4.2300
# Epoch 57/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3823 - loss: 4.0205 - val_accuracy: 0.3554 - val_loss: 4.2458
# Epoch 58/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3943 - loss: 3.9389 - val_accuracy: 0.3595 - val_loss: 4.2511
# Epoch 59/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3922 - loss: 3.9856 - val_accuracy: 0.3719 - val_loss: 4.2666
# Epoch 60/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3778 - loss: 4.1048 - val_accuracy: 0.3678 - val_loss: 4.2575
# Epoch 61/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3676 - loss: 4.0479 - val_accuracy: 0.3678 - val_loss: 4.2648
# Epoch 62/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3621 - loss: 4.0851 - val_accuracy: 0.3388 - val_loss: 4.2471
# Epoch 63/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3940 - loss: 3.9287 - val_accuracy: 0.3512 - val_loss: 4.2585
# Epoch 64/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3763 - loss: 3.9935 - val_accuracy: 0.3512 - val_loss: 4.2536
# Epoch 65/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3588 - loss: 4.1198 - val_accuracy: 0.3595 - val_loss: 4.2592
# Epoch 66/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3723 - loss: 4.0758 - val_accuracy: 0.3471 - val_loss: 4.2746
# Epoch 67/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3594 - loss: 4.0483 - val_accuracy: 0.3678 - val_loss: 4.2526
# Epoch 68/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3638 - loss: 4.0203 - val_accuracy: 0.3678 - val_loss: 4.2622
# Epoch 69/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3577 - loss: 4.0367 - val_accuracy: 0.3636 - val_loss: 4.2652
# Epoch 70/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3749 - loss: 4.0717 - val_accuracy: 0.3471 - val_loss: 4.2585
# Epoch 71/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3968 - loss: 4.0059 - val_accuracy: 0.3388 - val_loss: 4.2543
# Epoch 72/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3911 - loss: 4.0418 - val_accuracy: 0.3636 - val_loss: 4.2453
# Epoch 73/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3860 - loss: 4.0421 - val_accuracy: 0.3512 - val_loss: 4.2539
# Epoch 74/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3809 - loss: 4.0324 - val_accuracy: 0.3636 - val_loss: 4.2587
# Epoch 75/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3747 - loss: 4.0388 - val_accuracy: 0.3719 - val_loss: 4.2713
# Epoch 76/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3973 - loss: 4.0278 - val_accuracy: 0.3430 - val_loss: 4.2838
# Epoch 77/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3917 - loss: 3.9344 - val_accuracy: 0.3388 - val_loss: 4.2758
# Epoch 78/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3925 - loss: 3.9503 - val_accuracy: 0.3471 - val_loss: 4.2995
# Epoch 79/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3663 - loss: 4.0276 - val_accuracy: 0.3678 - val_loss: 4.2975
# Epoch 80/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3750 - loss: 4.0412 - val_accuracy: 0.3430 - val_loss: 4.2792
# Epoch 81/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3684 - loss: 4.0567 - val_accuracy: 0.3512 - val_loss: 4.3042
# Epoch 82/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3639 - loss: 4.0404 - val_accuracy: 0.3678 - val_loss: 4.2946
# Epoch 83/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3916 - loss: 4.0792 - val_accuracy: 0.3512 - val_loss: 4.3020
# Epoch 84/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3751 - loss: 3.9890 - val_accuracy: 0.3347 - val_loss: 4.3256
# Epoch 85/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3809 - loss: 3.8630 - val_accuracy: 0.3554 - val_loss: 4.3012
# Epoch 86/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4021 - loss: 3.8815 - val_accuracy: 0.3512 - val_loss: 4.2902
# Epoch 87/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3779 - loss: 4.0749 - val_accuracy: 0.3306 - val_loss: 4.2965
# Epoch 88/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3866 - loss: 4.0099 - val_accuracy: 0.3306 - val_loss: 4.2971
# Epoch 89/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3682 - loss: 4.1007 - val_accuracy: 0.3471 - val_loss: 4.3024
# Epoch 90/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3981 - loss: 3.8611 - val_accuracy: 0.3347 - val_loss: 4.3208
# Epoch 91/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3721 - loss: 4.1505 - val_accuracy: 0.3636 - val_loss: 4.3109
# Epoch 92/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3663 - loss: 4.0302 - val_accuracy: 0.3388 - val_loss: 4.3091
# Epoch 93/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3689 - loss: 4.1153 - val_accuracy: 0.3347 - val_loss: 4.3153
# Epoch 94/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3946 - loss: 3.9345 - val_accuracy: 0.3182 - val_loss: 4.3231
# Epoch 95/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4007 - loss: 3.9017 - val_accuracy: 0.3182 - val_loss: 4.3140
# Epoch 96/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3842 - loss: 3.9967 - val_accuracy: 0.3595 - val_loss: 4.3017
# Epoch 97/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4115 - loss: 3.9051 - val_accuracy: 0.3512 - val_loss: 4.3150
# Epoch 98/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3844 - loss: 3.9860 - val_accuracy: 0.3471 - val_loss: 4.3088
# Epoch 99/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3775 - loss: 3.9524 - val_accuracy: 0.3512 - val_loss: 4.3368
# Epoch 100/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4049 - loss: 3.8417 - val_accuracy: 0.2975 - val_loss: 4.3615

# %%
predictions = model.predict(val_data[x_variables])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %%
predicted_classes = predictions.argmax(axis=1)

# %%
predicted_classes
# Out:
# array([10, 10, 15, 15, 10, 10, 10, 10, 10, 10, 10, 10, 10])

# %%
predicted_true = np.argmax(val_data[y_variables].values, axis=1)

# %%
predicted_true
# Out:
# array([17, 15, 15,  4, 10, 10, 17, 10, 10, 15, 10,  8,  8])

# %%
# Cálculo de precisión
accuracy = accuracy_score(predicted_true, predicted_classes)
print(f"Precisión: {accuracy:.2f}")
# Out:
# Precisión: 0.46

# %%
all_results = []
for i, row in enumerate(predictions):
    row_results = []
    for formation, prob in zip(y_variables, row):
        row_results.append((formation, round(prob * 100, 2)))  # Convertir probabilidad a porcentaje
    row_results.append((val_data['Formación del oponente'].tolist()[i], 100))
    row_results.sort(key=lambda x: x[1], reverse=True)  # Ordenar de mayor a menor
    all_results.append(row_results)

# Mostrar resultados
for i, row_results in enumerate(all_results):
    print(f"\nResultados para el Partido {i + 1}:")
    for formation, percentage in row_results:
      if percentage == 100:
        print(f"Formacion real del partido: {formation}")
      else:
        formation=formation.replace('vst_','')
        print(f"Formación: {formation}, Probabilidad: {percentage}%")
# Out:
# Resultados para el Partido 1:
# Formacion real del partido: 5-3-2
# Formación: 4-2-3-1, Probabilidad: 50.14%
# Formación: 4-4-2, Probabilidad: 19.37%
# Formación: 4-3-3, Probabilidad: 10.36%
# Formación: 3-4-3, Probabilidad: 4.59%
# Formación: 5-4-1, Probabilidad: 2.77%
# Formación: 4-1-4-1, Probabilidad: 2.31%
# Formación: 4-3-1-2, Probabilidad: 2.0%
# Formación: 3-5-2, Probabilidad: 1.7%
# Formación: 4-4-1-1, Probabilidad: 1.62%
# Formación: 3-4-1-2, Probabilidad: 1.54%
# Formación: 4-2-2-2, Probabilidad: 1.53%
# Formación: 3-1-4-2, Probabilidad: 0.63%
# Formación: 4-5-1, Probabilidad: 0.53%
# Formación: 5-3-2, Probabilidad: 0.39%
# Formación: 4-3-2-1, Probabilidad: 0.18%
# Formación: 3-4-2-1, Probabilidad: 0.15%
# Formación: 4-1-3-2, Probabilidad: 0.11%
# Formación: 3-3-3-1, Probabilidad: 0.05%
# Formación: 3-5-1-1, Probabilidad: 0.04%
#
# Resultados para el Partido 2:
# Formacion real del partido: 4-4-2
# Formación: 4-2-3-1, Probabilidad: 46.74%
# Formación: 4-4-2, Probabilidad: 21.45%
# Formación: 4-3-3, Probabilidad: 10.71%
# Formación: 3-4-3, Probabilidad: 4.99%
# Formación: 5-4-1, Probabilidad: 2.94%
# Formación: 4-1-4-1, Probabilidad: 2.6%
# Formación: 3-5-2, Probabilidad: 1.84%
# Formación: 4-3-1-2, Probabilidad: 1.83%
# Formación: 4-2-2-2, Probabilidad: 1.65%
# Formación: 4-4-1-1, Probabilidad: 1.62%
# Formación: 3-4-1-2, Probabilidad: 1.46%
# Formación: 4-5-1, Probabilidad: 0.62%
# Formación: 3-1-4-2, Probabilidad: 0.57%
# Formación: 5-3-2, Probabilidad: 0.45%
# Formación: 4-3-2-1, Probabilidad: 0.18%
# Formación: 3-4-2-1, Probabilidad: 0.15%
# Formación: 4-1-3-2, Probabilidad: 0.12%
# Formación: 3-3-3-1, Probabilidad: 0.05%
# Formación: 3-5-1-1, Probabilidad: 0.04%
#
# Resultados para el Partido 3:
# Formacion real del partido: 4-4-2
# Formación: 4-4-2, Probabilidad: 27.46%
# Formación: 4-2-3-1, Probabilidad: 27.33%
# Formación: 3-4-3, Probabilidad: 23.96%
# Formación: 4-3-3, Probabilidad: 18.52%
# Formación: 4-4-1-1, Probabilidad: 0.65%
# Formación: 3-5-2, Probabilidad: 0.61%
# Formación: 4-5-1, Probabilidad: 0.55%
# Formación: 5-4-1, Probabilidad: 0.33%
# Formación: 4-1-4-1, Probabilidad: 0.25%
# Formación: 5-3-2, Probabilidad: 0.22%
# Formación: 3-4-1-2, Probabilidad: 0.09%
# Formación: 3-1-4-2, Probabilidad: 0.01%
# Formación: 4-2-2-2, Probabilidad: 0.01%
# Formación: 4-3-2-1, Probabilidad: 0.01%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
#
# Resultados para el Partido 4:
# Formacion real del partido: 3-4-3
# Formación: 4-4-2, Probabilidad: 37.64%
# Formación: 4-2-3-1, Probabilidad: 17.85%
# Formación: 4-3-3, Probabilidad: 17.14%
# Formación: 3-5-2, Probabilidad: 8.22%
# Formación: 5-3-2, Probabilidad: 6.17%
# Formación: 3-4-3, Probabilidad: 4.69%
# Formación: 5-4-1, Probabilidad: 3.54%
# Formación: 4-3-2-1, Probabilidad: 1.41%
# Formación: 4-5-1, Probabilidad: 1.3%
# Formación: 4-1-4-1, Probabilidad: 0.83%
# Formación: 4-4-1-1, Probabilidad: 0.66%
# Formación: 3-4-1-2, Probabilidad: 0.23%
# Formación: 4-3-1-2, Probabilidad: 0.2%
# Formación: 4-2-2-2, Probabilidad: 0.06%
# Formación: 3-5-1-1, Probabilidad: 0.02%
# Formación: 3-3-3-1, Probabilidad: 0.01%
# Formación: 3-4-2-1, Probabilidad: 0.01%
# Formación: 3-1-4-2, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
#
# Resultados para el Partido 5:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 46.44%
# Formación: 4-4-2, Probabilidad: 21.22%
# Formación: 4-3-3, Probabilidad: 11.01%
# Formación: 3-4-3, Probabilidad: 4.91%
# Formación: 5-4-1, Probabilidad: 3.17%
# Formación: 4-1-4-1, Probabilidad: 2.52%
# Formación: 3-5-2, Probabilidad: 1.98%
# Formación: 4-3-1-2, Probabilidad: 1.9%
# Formación: 4-4-1-1, Probabilidad: 1.61%
# Formación: 4-2-2-2, Probabilidad: 1.6%
# Formación: 3-4-1-2, Probabilidad: 1.41%
# Formación: 4-5-1, Probabilidad: 0.6%
# Formación: 3-1-4-2, Probabilidad: 0.52%
# Formación: 5-3-2, Probabilidad: 0.52%
# Formación: 4-3-2-1, Probabilidad: 0.21%
# Formación: 3-4-2-1, Probabilidad: 0.15%
# Formación: 4-1-3-2, Probabilidad: 0.12%
# Formación: 3-3-3-1, Probabilidad: 0.05%
# Formación: 3-5-1-1, Probabilidad: 0.05%
#
# Resultados para el Partido 6:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 55.07%
# Formación: 4-4-2, Probabilidad: 11.68%
# Formación: 4-3-3, Probabilidad: 9.46%
# Formación: 3-4-3, Probabilidad: 5.03%
# Formación: 4-1-4-1, Probabilidad: 3.66%
# Formación: 4-2-2-2, Probabilidad: 3.53%
# Formación: 4-3-1-2, Probabilidad: 2.46%
# Formación: 3-4-1-2, Probabilidad: 1.97%
# Formación: 5-4-1, Probabilidad: 1.89%
# Formación: 3-1-4-2, Probabilidad: 1.59%
# Formación: 4-4-1-1, Probabilidad: 1.28%
# Formación: 3-5-2, Probabilidad: 1.15%
# Formación: 4-5-1, Probabilidad: 0.4%
# Formación: 4-1-3-2, Probabilidad: 0.35%
# Formación: 3-4-2-1, Probabilidad: 0.26%
# Formación: 5-3-2, Probabilidad: 0.14%
# Formación: 4-3-2-1, Probabilidad: 0.06%
# Formación: 3-5-1-1, Probabilidad: 0.03%
# Formación: 3-3-3-1, Probabilidad: 0.02%
#
# Resultados para el Partido 7:
# Formacion real del partido: 5-3-2
# Formación: 4-2-3-1, Probabilidad: 27.51%
# Formación: 4-4-2, Probabilidad: 23.36%
# Formación: 4-3-3, Probabilidad: 13.3%
# Formación: 5-4-1, Probabilidad: 8.85%
# Formación: 3-4-3, Probabilidad: 6.54%
# Formación: 3-5-2, Probabilidad: 6.27%
# Formación: 5-3-2, Probabilidad: 3.83%
# Formación: 4-1-4-1, Probabilidad: 3.44%
# Formación: 4-2-2-2, Probabilidad: 1.4%
# Formación: 4-3-1-2, Probabilidad: 1.32%
# Formación: 4-3-2-1, Probabilidad: 1.09%
# Formación: 3-4-1-2, Probabilidad: 1.06%
# Formación: 4-5-1, Probabilidad: 0.94%
# Formación: 4-4-1-1, Probabilidad: 0.64%
# Formación: 3-5-1-1, Probabilidad: 0.22%
# Formación: 3-4-2-1, Probabilidad: 0.13%
# Formación: 3-1-4-2, Probabilidad: 0.04%
# Formación: 3-3-3-1, Probabilidad: 0.03%
# Formación: 4-1-3-2, Probabilidad: 0.03%
#
# Resultados para el Partido 8:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 38.14%
# Formación: 4-4-2, Probabilidad: 26.28%
# Formación: 4-3-3, Probabilidad: 12.95%
# Formación: 3-4-3, Probabilidad: 5.62%
# Formación: 4-1-4-1, Probabilidad: 4.48%
# Formación: 4-4-1-1, Probabilidad: 3.65%
# Formación: 3-1-4-2, Probabilidad: 3.04%
# Formación: 4-5-1, Probabilidad: 1.32%
# Formación: 4-3-1-2, Probabilidad: 0.97%
# Formación: 3-5-2, Probabilidad: 0.93%
# Formación: 3-4-1-2, Probabilidad: 0.58%
# Formación: 4-2-2-2, Probabilidad: 0.57%
# Formación: 5-3-2, Probabilidad: 0.4%
# Formación: 3-4-2-1, Probabilidad: 0.34%
# Formación: 5-4-1, Probabilidad: 0.29%
# Formación: 3-3-3-1, Probabilidad: 0.23%
# Formación: 4-3-2-1, Probabilidad: 0.18%
# Formación: 4-1-3-2, Probabilidad: 0.01%
# Formación: 3-5-1-1, Probabilidad: 0.0%
#
# Resultados para el Partido 9:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 61.1%
# Formación: 4-4-2, Probabilidad: 9.8%
# Formación: 4-3-3, Probabilidad: 8.03%
# Formación: 3-4-3, Probabilidad: 4.07%
# Formación: 4-2-2-2, Probabilidad: 2.87%
# Formación: 4-1-4-1, Probabilidad: 2.82%
# Formación: 4-3-1-2, Probabilidad: 2.49%
# Formación: 3-4-1-2, Probabilidad: 2.2%
# Formación: 3-1-4-2, Probabilidad: 1.77%
# Formación: 5-4-1, Probabilidad: 1.62%
# Formación: 4-4-1-1, Probabilidad: 1.35%
# Formación: 3-5-2, Probabilidad: 0.91%
# Formación: 4-5-1, Probabilidad: 0.3%
# Formación: 4-1-3-2, Probabilidad: 0.24%
# Formación: 3-4-2-1, Probabilidad: 0.23%
# Formación: 5-3-2, Probabilidad: 0.11%
# Formación: 4-3-2-1, Probabilidad: 0.06%
# Formación: 3-3-3-1, Probabilidad: 0.02%
# Formación: 3-5-1-1, Probabilidad: 0.02%
#
# Resultados para el Partido 10:
# Formacion real del partido: 4-4-2
# Formación: 4-2-3-1, Probabilidad: 34.77%
# Formación: 4-4-2, Probabilidad: 33.64%
# Formación: 4-3-3, Probabilidad: 8.51%
# Formación: 3-4-3, Probabilidad: 7.51%
# Formación: 5-4-1, Probabilidad: 3.06%
# Formación: 4-4-1-1, Probabilidad: 2.63%
# Formación: 3-5-2, Probabilidad: 2.59%
# Formación: 5-3-2, Probabilidad: 2.19%
# Formación: 4-5-1, Probabilidad: 1.62%
# Formación: 4-1-4-1, Probabilidad: 1.44%
# Formación: 4-3-2-1, Probabilidad: 1.29%
# Formación: 3-4-1-2, Probabilidad: 0.47%
# Formación: 4-2-2-2, Probabilidad: 0.17%
# Formación: 4-3-1-2, Probabilidad: 0.07%
# Formación: 3-1-4-2, Probabilidad: 0.02%
# Formación: 3-3-3-1, Probabilidad: 0.01%
# Formación: 3-4-2-1, Probabilidad: 0.01%
# Formación: 3-5-1-1, Probabilidad: 0.01%
# Formación: 4-1-3-2, Probabilidad: 0.01%
#
# Resultados para el Partido 11:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 42.58%
# Formación: 4-4-2, Probabilidad: 20.86%
# Formación: 4-3-3, Probabilidad: 10.91%
# Formación: 3-4-3, Probabilidad: 5.92%
# Formación: 4-1-4-1, Probabilidad: 5.54%
# Formación: 3-1-4-2, Probabilidad: 4.57%
# Formación: 4-4-1-1, Probabilidad: 3.58%
# Formación: 4-5-1, Probabilidad: 1.21%
# Formación: 4-3-1-2, Probabilidad: 1.06%
# Formación: 4-2-2-2, Probabilidad: 0.86%
# Formación: 3-4-1-2, Probabilidad: 0.77%
# Formación: 3-5-2, Probabilidad: 0.77%
# Formación: 3-4-2-1, Probabilidad: 0.44%
# Formación: 5-3-2, Probabilidad: 0.28%
# Formación: 5-4-1, Probabilidad: 0.28%
# Formación: 3-3-3-1, Probabilidad: 0.21%
# Formación: 4-3-2-1, Probabilidad: 0.13%
# Formación: 4-1-3-2, Probabilidad: 0.02%
# Formación: 3-5-1-1, Probabilidad: 0.0%
#
# Resultados para el Partido 12:
# Formacion real del partido: 4-1-4-1
# Formación: 4-2-3-1, Probabilidad: 48.97%
# Formación: 4-4-2, Probabilidad: 24.05%
# Formación: 4-3-3, Probabilidad: 8.84%
# Formación: 3-4-3, Probabilidad: 5.57%
# Formación: 4-1-4-1, Probabilidad: 3.96%
# Formación: 4-4-1-1, Probabilidad: 3.2%
# Formación: 4-5-1, Probabilidad: 1.2%
# Formación: 4-2-2-2, Probabilidad: 0.96%
# Formación: 3-5-2, Probabilidad: 0.93%
# Formación: 5-4-1, Probabilidad: 0.73%
# Formación: 3-4-1-2, Probabilidad: 0.67%
# Formación: 5-3-2, Probabilidad: 0.3%
# Formación: 4-3-2-1, Probabilidad: 0.25%
# Formación: 3-1-4-2, Probabilidad: 0.17%
# Formación: 4-3-1-2, Probabilidad: 0.14%
# Formación: 3-4-2-1, Probabilidad: 0.02%
# Formación: 4-1-3-2, Probabilidad: 0.02%
# Formación: 3-3-3-1, Probabilidad: 0.01%
# Formación: 3-5-1-1, Probabilidad: 0.0%
#
# Resultados para el Partido 13:
# Formacion real del partido: 4-1-4-1
# Formación: 4-2-3-1, Probabilidad: 53.38%
# Formación: 4-4-2, Probabilidad: 14.49%
# Formación: 4-3-3, Probabilidad: 9.94%
# Formación: 3-4-3, Probabilidad: 4.77%
# Formación: 4-1-4-1, Probabilidad: 2.84%
# Formación: 4-3-1-2, Probabilidad: 2.67%
# Formación: 5-4-1, Probabilidad: 2.41%
# Formación: 4-2-2-2, Probabilidad: 2.27%
# Formación: 3-4-1-2, Probabilidad: 1.86%
# Formación: 3-5-2, Probabilidad: 1.48%
# Formación: 4-4-1-1, Probabilidad: 1.45%
# Formación: 3-1-4-2, Probabilidad: 1.12%
# Formación: 4-5-1, Probabilidad: 0.45%
# Formación: 5-3-2, Probabilidad: 0.24%
# Formación: 3-4-2-1, Probabilidad: 0.23%
# Formación: 4-1-3-2, Probabilidad: 0.22%
# Formación: 4-3-2-1, Probabilidad: 0.11%
# Formación: 3-3-3-1, Probabilidad: 0.04%
# Formación: 3-5-1-1, Probabilidad: 0.04%

# %% [markdown]
# ## **MODELO DE RANDOM FOREST**

# %%
data_RF = df.copy()

# %%
y_variables = "Formación del oponente"

x_variables = [
    "P. Victoria",
    "P. Empate",
    "P. Perdida",
    "Saldo_Goles",
    "diferencia_altitud",
    "lcl_3-1-4-2",
    "lcl_3-2-4-1",
    "lcl_3-4-1-2",
    "lcl_3-4-3",
    "lcl_3-5-1-1",
    "lcl_3-5-2",
    "lcl_4-1-3-2",
    "lcl_4-1-4-1",
    "lcl_4-2-2-2",
    "lcl_4-2-3-1",
    "lcl_4-3-1-2",
    "lcl_4-3-2-1",
    "lcl_4-3-3",
    "lcl_4-4-1-1",
    "lcl_4-4-2",
    "lcl_4-5-1",
    "lcl_5-3-2",
    "lcl_5-4-1"
]

# %%
val_data = data_RF[(data_RF['Resultado'] == 'D') & (data_RF['Fecha'].dt.year == 2024) &(data_RF['clasificacion_del_partido'] == 'Altura vs Costa')]

# %%
test_data = data_RF[data_RF['Fecha'].dt.year == 2024]
train_data = data_RF[data_RF['Fecha'].dt.year != 2024]

# %%
# Asignar las variables de entrada y salida
X_train = train_data[x_variables]
y_train = train_data[y_variables]

X_test = test_data[x_variables]
y_test = test_data[y_variables]

# %%
weights_train = train_data['Resultado'].map({'V': 2, 'E': 1, 'D': 0})
weights_test = test_data['Resultado'].map({'V': 2, 'E': 1, 'D': 0})

# %%
from sklearn.ensemble import RandomForestClassifier
# Crear el modelo de Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
# Entrenar el modelo con pesos
rf.fit(X_train, y_train, sample_weight=weights_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_test
# Out:
# 0        4-3-3
# 1      4-2-3-1
# 2        3-4-3
# 3        4-4-2
# 4        4-4-2
#         ...
# 237      5-3-2
# 238      4-3-3
# 239    4-1-4-1
# 240    4-2-3-1
# 241      4-3-3
# Name: Formación del oponente, Length: 242, dtype: object

# %%
# Predicción en el conjunto de prueba
y_pred = rf.predict(val_data[x_variables])

# %%
# Obtener las probabilidades de cada clase
probabilities = rf.predict_proba(val_data[x_variables])
# Obtener las clases
classes = rf.classes_

# %%
from sklearn.metrics import accuracy_score, classification_report
# Evaluar el rendimiento del modelo
print("Accuracy:", accuracy_score(val_data[y_variables], y_pred))
print(classification_report(val_data[y_variables], y_pred))
# Out:
# Accuracy: 0.23076923076923078
#               precision    recall  f1-score   support
#
#        3-4-3       0.00      0.00      0.00         1
#      4-1-4-1       0.00      0.00      0.00         2
#      4-2-3-1       0.33      0.60      0.43         5
#        4-4-2       0.00      0.00      0.00         3
#        5-3-2       0.00      0.00      0.00         2
#
#     accuracy                           0.23        13
#    macro avg       0.07      0.12      0.09        13
# weighted avg       0.13      0.23      0.16        13
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
resultados = []
for probabilidad in  probabilities:
  lista =[]
  for clase, prob in zip(classes, probabilidad):
    #lista.append((clase, prob*100))
    lista.append((clase, round(prob*100,2)))
  lista.sort(key=lambda x: x[1], reverse=True)
  resultados.append(lista)

# %%
all_results = []
for i, row in enumerate(resultados):
    row_results = []
    for formation, prob in row:  # Iterate through tuples in row
        row_results.append((formation, round(prob, 2)))  # Round the probability value
    #row_results.append((verdaderos_v[i], 100))
    row_results.append((val_data['Formación del oponente'].tolist()[i], 100))
    row_results.sort(key=lambda x: x[1], reverse=True)
    all_results.append(row_results)

# Mostrar resultados
for i, row_results in enumerate(all_results):
    print(f"\nResultados para el Partido {i + 1}:")
    for formation, percentage in row_results:
      if percentage == 100:
        print(f"Formacion real del partido: {formation}")
      else:
        formation=formation.replace('vst_','')
        print(f"Formación: {formation}, Probabilidad: {percentage}%")
# Out:
# Resultados para el Partido 1:
# Formacion real del partido: 5-3-2
# Formación: 4-2-3-1, Probabilidad: 68.0%
# Formación: 4-4-2, Probabilidad: 19.0%
# Formación: 3-4-3, Probabilidad: 4.0%
# Formación: 4-3-3, Probabilidad: 4.0%
# Formación: 5-4-1, Probabilidad: 2.0%
# Formación: 3-1-4-2, Probabilidad: 1.0%
# Formación: 4-1-4-1, Probabilidad: 1.0%
# Formación: 4-4-1-1, Probabilidad: 1.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-1-2, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 3-5-2, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-2-2-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 4-5-1, Probabilidad: 0.0%
# Formación: 5-3-2, Probabilidad: 0.0%
#
# Resultados para el Partido 2:
# Formacion real del partido: 4-4-2
# Formación: 4-2-3-1, Probabilidad: 65.0%
# Formación: 4-4-2, Probabilidad: 21.0%
# Formación: 3-4-3, Probabilidad: 4.0%
# Formación: 5-4-1, Probabilidad: 4.0%
# Formación: 4-4-1-1, Probabilidad: 3.0%
# Formación: 4-3-3, Probabilidad: 2.0%
# Formación: 3-5-2, Probabilidad: 1.0%
# Formación: 3-1-4-2, Probabilidad: 0.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-1-2, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-1-4-1, Probabilidad: 0.0%
# Formación: 4-2-2-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 4-5-1, Probabilidad: 0.0%
# Formación: 5-3-2, Probabilidad: 0.0%
#
# Resultados para el Partido 3:
# Formacion real del partido: 4-4-2
# Formación: 4-2-3-1, Probabilidad: 49.0%
# Formación: 4-4-2, Probabilidad: 23.0%
# Formación: 4-3-3, Probabilidad: 12.0%
# Formación: 3-4-3, Probabilidad: 7.0%
# Formación: 5-3-2, Probabilidad: 3.0%
# Formación: 4-4-1-1, Probabilidad: 2.0%
# Formación: 4-5-1, Probabilidad: 2.0%
# Formación: 3-1-4-2, Probabilidad: 1.0%
# Formación: 3-5-2, Probabilidad: 1.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-1-2, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-1-4-1, Probabilidad: 0.0%
# Formación: 4-2-2-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 5-4-1, Probabilidad: 0.0%
#
# Resultados para el Partido 4:
# Formacion real del partido: 3-4-3
# Formación: 4-4-2, Probabilidad: 22.0%
# Formación: 5-3-2, Probabilidad: 19.0%
# Formación: 4-2-3-1, Probabilidad: 17.0%
# Formación: 4-1-4-1, Probabilidad: 15.0%
# Formación: 4-3-3, Probabilidad: 11.0%
# Formación: 3-4-3, Probabilidad: 10.0%
# Formación: 3-5-2, Probabilidad: 2.0%
# Formación: 4-5-1, Probabilidad: 2.0%
# Formación: 5-4-1, Probabilidad: 2.0%
# Formación: 3-1-4-2, Probabilidad: 0.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-1-2, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-2-2-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 4-4-1-1, Probabilidad: 0.0%
#
# Resultados para el Partido 5:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 71.0%
# Formación: 4-4-2, Probabilidad: 14.0%
# Formación: 3-4-3, Probabilidad: 6.0%
# Formación: 4-3-3, Probabilidad: 4.0%
# Formación: 5-4-1, Probabilidad: 3.0%
# Formación: 3-4-1-2, Probabilidad: 1.0%
# Formación: 3-5-2, Probabilidad: 1.0%
# Formación: 3-1-4-2, Probabilidad: 0.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-1-4-1, Probabilidad: 0.0%
# Formación: 4-2-2-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 4-4-1-1, Probabilidad: 0.0%
# Formación: 4-5-1, Probabilidad: 0.0%
# Formación: 5-3-2, Probabilidad: 0.0%
#
# Resultados para el Partido 6:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 42.0%
# Formación: 4-3-3, Probabilidad: 18.0%
# Formación: 5-4-1, Probabilidad: 14.0%
# Formación: 4-4-2, Probabilidad: 9.0%
# Formación: 4-1-4-1, Probabilidad: 7.0%
# Formación: 3-5-2, Probabilidad: 4.0%
# Formación: 3-4-3, Probabilidad: 3.0%
# Formación: 4-5-1, Probabilidad: 2.0%
# Formación: 4-2-2-2, Probabilidad: 1.0%
# Formación: 3-1-4-2, Probabilidad: 0.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-1-2, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 4-4-1-1, Probabilidad: 0.0%
# Formación: 5-3-2, Probabilidad: 0.0%
#
# Resultados para el Partido 7:
# Formacion real del partido: 5-3-2
# Formación: 4-4-2, Probabilidad: 37.0%
# Formación: 4-3-3, Probabilidad: 22.0%
# Formación: 4-2-3-1, Probabilidad: 20.0%
# Formación: 3-4-3, Probabilidad: 8.0%
# Formación: 5-3-2, Probabilidad: 5.0%
# Formación: 4-1-4-1, Probabilidad: 3.0%
# Formación: 3-5-2, Probabilidad: 2.0%
# Formación: 5-4-1, Probabilidad: 2.0%
# Formación: 3-4-1-2, Probabilidad: 1.0%
# Formación: 3-1-4-2, Probabilidad: 0.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-2-2-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 4-4-1-1, Probabilidad: 0.0%
# Formación: 4-5-1, Probabilidad: 0.0%
#
# Resultados para el Partido 8:
# Formacion real del partido: 4-2-3-1
# Formación: 4-4-2, Probabilidad: 41.0%
# Formación: 4-3-3, Probabilidad: 22.0%
# Formación: 4-2-3-1, Probabilidad: 19.0%
# Formación: 4-4-1-1, Probabilidad: 7.0%
# Formación: 3-4-3, Probabilidad: 6.0%
# Formación: 3-1-4-2, Probabilidad: 2.0%
# Formación: 4-1-4-1, Probabilidad: 1.0%
# Formación: 5-3-2, Probabilidad: 1.0%
# Formación: 5-4-1, Probabilidad: 1.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-1-2, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 3-5-2, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-2-2-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 4-5-1, Probabilidad: 0.0%
#
# Resultados para el Partido 9:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 76.0%
# Formación: 4-3-3, Probabilidad: 16.0%
# Formación: 4-4-2, Probabilidad: 4.0%
# Formación: 4-1-4-1, Probabilidad: 3.0%
# Formación: 4-3-1-2, Probabilidad: 1.0%
# Formación: 3-1-4-2, Probabilidad: 0.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-1-2, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-4-3, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 3-5-2, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-2-2-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 4-4-1-1, Probabilidad: 0.0%
# Formación: 4-5-1, Probabilidad: 0.0%
# Formación: 5-3-2, Probabilidad: 0.0%
# Formación: 5-4-1, Probabilidad: 0.0%
#
# Resultados para el Partido 10:
# Formacion real del partido: 4-4-2
# Formación: 4-2-3-1, Probabilidad: 57.0%
# Formación: 4-4-2, Probabilidad: 14.0%
# Formación: 4-3-3, Probabilidad: 12.0%
# Formación: 3-5-2, Probabilidad: 6.0%
# Formación: 4-4-1-1, Probabilidad: 3.0%
# Formación: 3-4-1-2, Probabilidad: 2.0%
# Formación: 3-4-3, Probabilidad: 2.0%
# Formación: 5-3-2, Probabilidad: 2.0%
# Formación: 4-1-4-1, Probabilidad: 1.0%
# Formación: 5-4-1, Probabilidad: 1.0%
# Formación: 3-1-4-2, Probabilidad: 0.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-2-2-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 4-5-1, Probabilidad: 0.0%
#
# Resultados para el Partido 11:
# Formacion real del partido: 4-2-3-1
# Formación: 4-4-2, Probabilidad: 59.0%
# Formación: 4-2-3-1, Probabilidad: 22.0%
# Formación: 4-3-3, Probabilidad: 9.0%
# Formación: 4-1-4-1, Probabilidad: 8.0%
# Formación: 3-5-2, Probabilidad: 2.0%
# Formación: 3-1-4-2, Probabilidad: 0.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-1-2, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-4-3, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-2-2-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 4-4-1-1, Probabilidad: 0.0%
# Formación: 4-5-1, Probabilidad: 0.0%
# Formación: 5-3-2, Probabilidad: 0.0%
# Formación: 5-4-1, Probabilidad: 0.0%
#
# Resultados para el Partido 12:
# Formacion real del partido: 4-1-4-1
# Formación: 4-2-3-1, Probabilidad: 44.0%
# Formación: 4-1-4-1, Probabilidad: 17.0%
# Formación: 4-4-2, Probabilidad: 17.0%
# Formación: 4-3-3, Probabilidad: 14.0%
# Formación: 4-4-1-1, Probabilidad: 3.0%
# Formación: 3-5-2, Probabilidad: 2.0%
# Formación: 3-4-3, Probabilidad: 1.0%
# Formación: 4-5-1, Probabilidad: 1.0%
# Formación: 5-4-1, Probabilidad: 1.0%
# Formación: 3-1-4-2, Probabilidad: 0.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-1-2, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-2-2-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%
# Formación: 5-3-2, Probabilidad: 0.0%
#
# Resultados para el Partido 13:
# Formacion real del partido: 4-1-4-1
# Formación: 4-2-3-1, Probabilidad: 57.0%
# Formación: 4-3-3, Probabilidad: 13.0%
# Formación: 4-4-2, Probabilidad: 10.0%
# Formación: 3-4-3, Probabilidad: 7.0%
# Formación: 3-4-1-2, Probabilidad: 3.0%
# Formación: 4-4-1-1, Probabilidad: 3.0%
# Formación: 4-5-1, Probabilidad: 2.0%
# Formación: 3-1-4-2, Probabilidad: 1.0%
# Formación: 4-1-4-1, Probabilidad: 1.0%
# Formación: 4-2-2-2, Probabilidad: 1.0%
# Formación: 5-3-2, Probabilidad: 1.0%
# Formación: 5-4-1, Probabilidad: 1.0%
# Formación: 3-3-3-1, Probabilidad: 0.0%
# Formación: 3-4-2-1, Probabilidad: 0.0%
# Formación: 3-5-1-1, Probabilidad: 0.0%
# Formación: 3-5-2, Probabilidad: 0.0%
# Formación: 4-1-3-2, Probabilidad: 0.0%
# Formación: 4-3-1-2, Probabilidad: 0.0%
# Formación: 4-3-2-1, Probabilidad: 0.0%

# %% [markdown]
# ## **MODELO DE SVM**

# %%
data_SVM = df.copy()

# %%
y_variables = "Formación del oponente"

x_variables = [
    "P. Victoria",
    "P. Empate",
    "P. Perdida",
    "Saldo_Goles",
    "diferencia_altitud",
    "lcl_3-1-4-2",
    "lcl_3-2-4-1",
    "lcl_3-4-1-2",
    "lcl_3-4-3",
    "lcl_3-5-1-1",
    "lcl_3-5-2",
    "lcl_4-1-3-2",
    "lcl_4-1-4-1",
    "lcl_4-2-2-2",
    "lcl_4-2-3-1",
    "lcl_4-3-1-2",
    "lcl_4-3-2-1",
    "lcl_4-3-3",
    "lcl_4-4-1-1",
    "lcl_4-4-2",
    "lcl_4-5-1",
    "lcl_5-3-2",
    "lcl_5-4-1"
]

# %%
val_data = data_SVM[(data_SVM['Resultado'] == 'D') & (data_SVM['Fecha'].dt.year == 2024) &(data_SVM['clasificacion_del_partido'] == 'Altura vs Costa')]

# %%
test_data = data_SVM[data_SVM['Fecha'].dt.year == 2024]
train_data = data_SVM[data_SVM['Fecha'].dt.year != 2024]

# %%
# Asignar las variables de entrada y salida
X_train = train_data[x_variables]
y_train = train_data[y_variables]

X_test = test_data[x_variables]
y_test = test_data[y_variables]

# %%
sample_weights = train_data['Resultado'].map({'V': 3, 'E': 1, 'D': -3})

# %%
from sklearn.svm import SVC

# Entrenamiento del modelo SVM
svm_model = SVC(kernel='rbf', C=1.0, gamma='scale', probability=True)  # OvR para multiclase
svm_model.fit(X_train, y_train, sample_weight=sample_weights)
# Out:
# SVC(probability=True)

# %%
# Predicción y evaluación
y_pred = svm_model.predict(val_data[x_variables])

# %%
probabilities = svm_model.predict_proba(val_data[x_variables])

# %%
classes = svm_model.classes_

# %%
resultados = []
for probabilidad in  probabilities:
  lista =[]
  for clase, prob in zip(classes, probabilidad):
    #lista.append((clase, prob*100))
    lista.append((clase, round(prob*100,2)))
  lista.sort(key=lambda x: x[1], reverse=True)
  resultados.append(lista)

# %%
all_results = []
for i, row in enumerate(resultados):
    row_results = []
    for formation, prob in row:  # Iterate through tuples in row
        row_results.append((formation, round(prob, 2)))  # Round the probability value
    #row_results.append((verdaderos_v[i], 100))
    row_results.append((val_data['Formación del oponente'].tolist()[i], 100))
    row_results.sort(key=lambda x: x[1], reverse=True)
    all_results.append(row_results)

# Mostrar resultados
for i, row_results in enumerate(all_results):
    print(f"\nResultados para el Partido {i + 1}:")
    for formation, percentage in row_results:
      if percentage == 100:
        print(f"Formacion real del partido: {formation}")
      else:
        formation=formation.replace('vst_','')
        print(f"Formación: {formation}, Probabilidad: {percentage}%")
# Out:
# Resultados para el Partido 1:
# Formacion real del partido: 5-3-2
# Formación: 4-2-3-1, Probabilidad: 34.49%
# Formación: 4-4-2, Probabilidad: 25.28%
# Formación: 4-3-3, Probabilidad: 14.7%
# Formación: 3-4-3, Probabilidad: 7.84%
# Formación: 5-3-2, Probabilidad: 3.56%
# Formación: 4-1-4-1, Probabilidad: 3.15%
# Formación: 3-5-2, Probabilidad: 2.86%
# Formación: 5-4-1, Probabilidad: 2.53%
# Formación: 4-4-1-1, Probabilidad: 1.19%
# Formación: 4-5-1, Probabilidad: 1.16%
# Formación: 4-2-2-2, Probabilidad: 0.91%
# Formación: 4-3-2-1, Probabilidad: 0.47%
# Formación: 3-4-1-2, Probabilidad: 0.44%
# Formación: 4-3-1-2, Probabilidad: 0.37%
# Formación: 4-1-3-2, Probabilidad: 0.28%
# Formación: 3-1-4-2, Probabilidad: 0.27%
# Formación: 3-5-1-1, Probabilidad: 0.18%
# Formación: 3-3-3-1, Probabilidad: 0.17%
# Formación: 3-4-2-1, Probabilidad: 0.15%
#
# Resultados para el Partido 2:
# Formacion real del partido: 4-4-2
# Formación: 4-2-3-1, Probabilidad: 34.46%
# Formación: 4-4-2, Probabilidad: 25.31%
# Formación: 4-3-3, Probabilidad: 14.65%
# Formación: 3-4-3, Probabilidad: 7.84%
# Formación: 5-3-2, Probabilidad: 3.59%
# Formación: 4-1-4-1, Probabilidad: 3.16%
# Formación: 3-5-2, Probabilidad: 2.88%
# Formación: 5-4-1, Probabilidad: 2.52%
# Formación: 4-5-1, Probabilidad: 1.18%
# Formación: 4-4-1-1, Probabilidad: 1.17%
# Formación: 4-2-2-2, Probabilidad: 0.92%
# Formación: 4-3-2-1, Probabilidad: 0.47%
# Formación: 3-4-1-2, Probabilidad: 0.43%
# Formación: 4-3-1-2, Probabilidad: 0.38%
# Formación: 4-1-3-2, Probabilidad: 0.28%
# Formación: 3-1-4-2, Probabilidad: 0.27%
# Formación: 3-5-1-1, Probabilidad: 0.18%
# Formación: 3-3-3-1, Probabilidad: 0.17%
# Formación: 3-4-2-1, Probabilidad: 0.15%
#
# Resultados para el Partido 3:
# Formacion real del partido: 4-4-2
# Formación: 4-2-3-1, Probabilidad: 34.2%
# Formación: 4-4-2, Probabilidad: 24.4%
# Formación: 4-3-3, Probabilidad: 15.76%
# Formación: 3-4-3, Probabilidad: 8.23%
# Formación: 4-1-4-1, Probabilidad: 3.44%
# Formación: 5-3-2, Probabilidad: 3.25%
# Formación: 3-5-2, Probabilidad: 2.83%
# Formación: 5-4-1, Probabilidad: 2.56%
# Formación: 4-4-1-1, Probabilidad: 1.28%
# Formación: 4-5-1, Probabilidad: 0.88%
# Formación: 4-2-2-2, Probabilidad: 0.58%
# Formación: 4-3-2-1, Probabilidad: 0.51%
# Formación: 3-4-1-2, Probabilidad: 0.49%
# Formación: 4-3-1-2, Probabilidad: 0.49%
# Formación: 3-1-4-2, Probabilidad: 0.41%
# Formación: 4-1-3-2, Probabilidad: 0.25%
# Formación: 3-3-3-1, Probabilidad: 0.15%
# Formación: 3-4-2-1, Probabilidad: 0.15%
# Formación: 3-5-1-1, Probabilidad: 0.14%
#
# Resultados para el Partido 4:
# Formacion real del partido: 3-4-3
# Formación: 4-2-3-1, Probabilidad: 34.74%
# Formación: 4-4-2, Probabilidad: 26.11%
# Formación: 4-3-3, Probabilidad: 13.01%
# Formación: 3-4-3, Probabilidad: 7.63%
# Formación: 5-3-2, Probabilidad: 4.52%
# Formación: 5-4-1, Probabilidad: 2.82%
# Formación: 4-1-4-1, Probabilidad: 2.67%
# Formación: 3-5-2, Probabilidad: 2.6%
# Formación: 4-4-1-1, Probabilidad: 1.19%
# Formación: 4-5-1, Probabilidad: 1.04%
# Formación: 4-3-1-2, Probabilidad: 0.82%
# Formación: 3-4-1-2, Probabilidad: 0.59%
# Formación: 4-2-2-2, Probabilidad: 0.59%
# Formación: 4-3-2-1, Probabilidad: 0.52%
# Formación: 3-1-4-2, Probabilidad: 0.36%
# Formación: 4-1-3-2, Probabilidad: 0.28%
# Formación: 3-4-2-1, Probabilidad: 0.18%
# Formación: 3-3-3-1, Probabilidad: 0.17%
# Formación: 3-5-1-1, Probabilidad: 0.16%
#
# Resultados para el Partido 5:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 34.43%
# Formación: 4-4-2, Probabilidad: 25.3%
# Formación: 4-3-3, Probabilidad: 14.67%
# Formación: 3-4-3, Probabilidad: 7.84%
# Formación: 5-3-2, Probabilidad: 3.6%
# Formación: 4-1-4-1, Probabilidad: 3.18%
# Formación: 3-5-2, Probabilidad: 2.87%
# Formación: 5-4-1, Probabilidad: 2.54%
# Formación: 4-4-1-1, Probabilidad: 1.17%
# Formación: 4-5-1, Probabilidad: 1.15%
# Formación: 4-2-2-2, Probabilidad: 0.92%
# Formación: 4-3-2-1, Probabilidad: 0.47%
# Formación: 3-4-1-2, Probabilidad: 0.44%
# Formación: 4-3-1-2, Probabilidad: 0.37%
# Formación: 4-1-3-2, Probabilidad: 0.28%
# Formación: 3-1-4-2, Probabilidad: 0.26%
# Formación: 3-5-1-1, Probabilidad: 0.18%
# Formación: 3-3-3-1, Probabilidad: 0.17%
# Formación: 3-4-2-1, Probabilidad: 0.15%
#
# Resultados para el Partido 6:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 34.48%
# Formación: 4-4-2, Probabilidad: 24.85%
# Formación: 4-3-3, Probabilidad: 15.12%
# Formación: 3-4-3, Probabilidad: 7.89%
# Formación: 4-1-4-1, Probabilidad: 3.75%
# Formación: 5-3-2, Probabilidad: 3.33%
# Formación: 3-5-2, Probabilidad: 2.83%
# Formación: 5-4-1, Probabilidad: 2.44%
# Formación: 4-4-1-1, Probabilidad: 1.19%
# Formación: 4-5-1, Probabilidad: 1.03%
# Formación: 4-2-2-2, Probabilidad: 0.9%
# Formación: 4-3-2-1, Probabilidad: 0.46%
# Formación: 3-4-1-2, Probabilidad: 0.42%
# Formación: 3-1-4-2, Probabilidad: 0.31%
# Formación: 4-3-1-2, Probabilidad: 0.31%
# Formación: 4-1-3-2, Probabilidad: 0.25%
# Formación: 3-3-3-1, Probabilidad: 0.17%
# Formación: 3-4-2-1, Probabilidad: 0.14%
# Formación: 3-5-1-1, Probabilidad: 0.12%
#
# Resultados para el Partido 7:
# Formacion real del partido: 5-3-2
# Formación: 4-2-3-1, Probabilidad: 34.27%
# Formación: 4-4-2, Probabilidad: 25.49%
# Formación: 4-3-3, Probabilidad: 14.38%
# Formación: 3-4-3, Probabilidad: 7.84%
# Formación: 5-3-2, Probabilidad: 4.09%
# Formación: 3-5-2, Probabilidad: 2.87%
# Formación: 4-1-4-1, Probabilidad: 2.87%
# Formación: 5-4-1, Probabilidad: 2.53%
# Formación: 4-5-1, Probabilidad: 1.18%
# Formación: 4-4-1-1, Probabilidad: 1.12%
# Formación: 4-2-2-2, Probabilidad: 0.94%
# Formación: 4-3-2-1, Probabilidad: 0.48%
# Formación: 3-4-1-2, Probabilidad: 0.43%
# Formación: 4-3-1-2, Probabilidad: 0.42%
# Formación: 4-1-3-2, Probabilidad: 0.31%
# Formación: 3-1-4-2, Probabilidad: 0.24%
# Formación: 3-5-1-1, Probabilidad: 0.18%
# Formación: 3-3-3-1, Probabilidad: 0.17%
# Formación: 3-4-2-1, Probabilidad: 0.16%
#
# Resultados para el Partido 8:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 34.82%
# Formación: 4-4-2, Probabilidad: 25.7%
# Formación: 4-3-3, Probabilidad: 14.49%
# Formación: 3-4-3, Probabilidad: 7.44%
# Formación: 4-1-4-1, Probabilidad: 3.56%
# Formación: 5-3-2, Probabilidad: 3.19%
# Formación: 3-5-2, Probabilidad: 2.55%
# Formación: 4-4-1-1, Probabilidad: 1.77%
# Formación: 5-4-1, Probabilidad: 1.58%
# Formación: 3-1-4-2, Probabilidad: 1.38%
# Formación: 4-5-1, Probabilidad: 0.97%
# Formación: 4-2-2-2, Probabilidad: 0.5%
# Formación: 3-4-1-2, Probabilidad: 0.45%
# Formación: 4-3-2-1, Probabilidad: 0.44%
# Formación: 4-3-1-2, Probabilidad: 0.39%
# Formación: 4-1-3-2, Probabilidad: 0.25%
# Formación: 3-4-2-1, Probabilidad: 0.19%
# Formación: 3-5-1-1, Probabilidad: 0.17%
# Formación: 3-3-3-1, Probabilidad: 0.15%
#
# Resultados para el Partido 9:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 34.56%
# Formación: 4-4-2, Probabilidad: 24.88%
# Formación: 4-3-3, Probabilidad: 15.13%
# Formación: 3-4-3, Probabilidad: 7.89%
# Formación: 4-1-4-1, Probabilidad: 3.68%
# Formación: 5-3-2, Probabilidad: 3.32%
# Formación: 3-5-2, Probabilidad: 2.82%
# Formación: 5-4-1, Probabilidad: 2.45%
# Formación: 4-4-1-1, Probabilidad: 1.2%
# Formación: 4-5-1, Probabilidad: 1.0%
# Formación: 4-2-2-2, Probabilidad: 0.87%
# Formación: 4-3-2-1, Probabilidad: 0.46%
# Formación: 3-4-1-2, Probabilidad: 0.42%
# Formación: 3-1-4-2, Probabilidad: 0.33%
# Formación: 4-3-1-2, Probabilidad: 0.3%
# Formación: 4-1-3-2, Probabilidad: 0.24%
# Formación: 3-3-3-1, Probabilidad: 0.16%
# Formación: 3-4-2-1, Probabilidad: 0.14%
# Formación: 3-5-1-1, Probabilidad: 0.13%
#
# Resultados para el Partido 10:
# Formacion real del partido: 4-4-2
# Formación: 4-2-3-1, Probabilidad: 34.57%
# Formación: 4-4-2, Probabilidad: 25.58%
# Formación: 4-3-3, Probabilidad: 14.24%
# Formación: 3-4-3, Probabilidad: 7.9%
# Formación: 5-3-2, Probabilidad: 3.67%
# Formación: 4-1-4-1, Probabilidad: 3.03%
# Formación: 3-5-2, Probabilidad: 2.83%
# Formación: 5-4-1, Probabilidad: 2.69%
# Formación: 4-4-1-1, Probabilidad: 1.3%
# Formación: 4-5-1, Probabilidad: 1.05%
# Formación: 4-3-1-2, Probabilidad: 0.55%
# Formación: 3-4-1-2, Probabilidad: 0.53%
# Formación: 4-2-2-2, Probabilidad: 0.51%
# Formación: 4-3-2-1, Probabilidad: 0.48%
# Formación: 3-1-4-2, Probabilidad: 0.33%
# Formación: 4-1-3-2, Probabilidad: 0.25%
# Formación: 3-4-2-1, Probabilidad: 0.16%
# Formación: 3-3-3-1, Probabilidad: 0.15%
# Formación: 3-5-1-1, Probabilidad: 0.14%
#
# Resultados para el Partido 11:
# Formacion real del partido: 4-2-3-1
# Formación: 4-2-3-1, Probabilidad: 35.39%
# Formación: 4-4-2, Probabilidad: 25.98%
# Formación: 4-3-3, Probabilidad: 14.59%
# Formación: 3-4-3, Probabilidad: 6.33%
# Formación: 4-1-4-1, Probabilidad: 3.71%
# Formación: 5-3-2, Probabilidad: 3.22%
# Formación: 3-5-2, Probabilidad: 2.58%
# Formación: 4-4-1-1, Probabilidad: 1.74%
# Formación: 5-4-1, Probabilidad: 1.52%
# Formación: 3-1-4-2, Probabilidad: 1.28%
# Formación: 4-5-1, Probabilidad: 1.04%
# Formación: 4-2-2-2, Probabilidad: 0.54%
# Formación: 4-3-2-1, Probabilidad: 0.45%
# Formación: 3-4-1-2, Probabilidad: 0.43%
# Formación: 4-3-1-2, Probabilidad: 0.39%
# Formación: 4-1-3-2, Probabilidad: 0.26%
# Formación: 3-4-2-1, Probabilidad: 0.2%
# Formación: 3-5-1-1, Probabilidad: 0.18%
# Formación: 3-3-3-1, Probabilidad: 0.16%
#
# Resultados para el Partido 12:
# Formacion real del partido: 4-1-4-1
# Formación: 4-2-3-1, Probabilidad: 34.81%
# Formación: 4-4-2, Probabilidad: 25.62%
# Formación: 4-3-3, Probabilidad: 14.49%
# Formación: 3-4-3, Probabilidad: 7.7%
# Formación: 4-1-4-1, Probabilidad: 3.96%
# Formación: 5-3-2, Probabilidad: 3.05%
# Formación: 3-5-2, Probabilidad: 2.68%
# Formación: 5-4-1, Probabilidad: 2.37%
# Formación: 4-4-1-1, Probabilidad: 1.24%
# Formación: 4-5-1, Probabilidad: 0.94%
# Formación: 4-3-1-2, Probabilidad: 0.54%
# Formación: 4-2-2-2, Probabilidad: 0.53%
# Formación: 3-4-1-2, Probabilidad: 0.5%
# Formación: 4-3-2-1, Probabilidad: 0.45%
# Formación: 3-1-4-2, Probabilidad: 0.42%
# Formación: 4-1-3-2, Probabilidad: 0.24%
# Formación: 3-4-2-1, Probabilidad: 0.16%
# Formación: 3-3-3-1, Probabilidad: 0.15%
# Formación: 3-5-1-1, Probabilidad: 0.13%
#
# Resultados para el Partido 13:
# Formacion real del partido: 4-1-4-1
# Formación: 4-2-3-1, Probabilidad: 34.42%
# Formación: 4-4-2, Probabilidad: 25.08%
# Formación: 4-3-3, Probabilidad: 14.93%
# Formación: 3-4-3, Probabilidad: 7.87%
# Formación: 4-1-4-1, Probabilidad: 3.47%
# Formación: 5-3-2, Probabilidad: 3.43%
# Formación: 3-5-2, Probabilidad: 2.85%
# Formación: 5-4-1, Probabilidad: 2.52%
# Formación: 4-4-1-1, Probabilidad: 1.2%
# Formación: 4-5-1, Probabilidad: 1.08%
# Formación: 4-2-2-2, Probabilidad: 0.9%
# Formación: 4-3-2-1, Probabilidad: 0.47%
# Formación: 3-4-1-2, Probabilidad: 0.43%
# Formación: 4-3-1-2, Probabilidad: 0.33%
# Formación: 3-1-4-2, Probabilidad: 0.29%
# Formación: 4-1-3-2, Probabilidad: 0.26%
# Formación: 3-3-3-1, Probabilidad: 0.17%
# Formación: 3-4-2-1, Probabilidad: 0.15%
# Formación: 3-5-1-1, Probabilidad: 0.15%

# %%
print("Precisión del modelo:", accuracy_score(val_data[y_variables], y_pred))
print("Reporte de clasificación:")
print(classification_report(val_data[y_variables], y_pred))
# Out:
# Precisión del modelo: 0.38461538461538464
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#        3-4-3       0.00      0.00      0.00         1
#      4-1-4-1       0.00      0.00      0.00         2
#      4-2-3-1       0.42      1.00      0.59         5
#        4-4-2       0.00      0.00      0.00         3
#        5-3-2       0.00      0.00      0.00         2
#
#     accuracy                           0.38        13
#    macro avg       0.08      0.20      0.12        13
# weighted avg       0.16      0.38      0.23        13
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## **MODELO DE TABNET**

# %%
data_TBN = df.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97977dcc1d3a> in <cell line: 1>()
# ----> 1 data_TBN = df.copy()
#
# NameError: name 'df' is not defined

# %%
y_variables = "Formación del oponente"

x_variables = [
    "P. Victoria",
    "P. Empate",
    "P. Perdida",
    "Saldo_Goles",
    "diferencia_altitud",
    "lcl_3-1-4-2",
    "lcl_3-2-4-1",
    "lcl_3-4-1-2",
    "lcl_3-4-3",
    "lcl_3-5-1-1",
    "lcl_3-5-2",
    "lcl_4-1-3-2",
    "lcl_4-1-4-1",
    "lcl_4-2-2-2",
    "lcl_4-2-3-1",
    "lcl_4-3-1-2",
    "lcl_4-3-2-1",
    "lcl_4-3-3",
    "lcl_4-4-1-1",
    "lcl_4-4-2",
    "lcl_4-5-1",
    "lcl_5-3-2",
    "lcl_5-4-1"
]

# %%
# Lista de formaciones a eliminar
formaciones_a_filtrar = ['3-3-3-1', '3-4-2-1', '3-5-1-1', '4-3-2-1', '3-1-4-2']

# Eliminar filas donde 'Formación del oponente' esté en la lista
data_TBN = data_TBN[~data_TBN['Formación del oponente'].isin(formaciones_a_filtrar)]

# Mostrar el DataFrame resultante
print(data_TBN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-66ffdf7076fa> in <cell line: 5>()
#       3
#       4 # Eliminar filas donde 'Formación del oponente' esté en la lista
# ----> 5 data_TBN = data_TBN[~data_TBN['Formación del oponente'].isin(formaciones_a_filtrar)]
#       6
#       7 # Mostrar el DataFrame resultante
#
# NameError: name 'data_TBN' is not defined

# %%
val_data = data_TBN[(data_TBN['Resultado'] == 'D') & (data_TBN['Fecha'].dt.year == 2024) &(data_TBN['clasificacion_del_partido'] == 'Altura vs Costa')]

# %%
test_data = data_TBN[data_TBN['Fecha'].dt.year == 2024]
train_data = data_TBN[data_TBN['Fecha'].dt.year != 2024]

# %%
# Asignar las variables de entrada y salida
X_train = train_data[x_variables]
y_train = train_data[y_variables]

X_test = test_data[x_variables]
y_test = test_data[y_variables]

# %%
print("Clases en y_true:", np.unique(y_train))
print("Clases en y_pred:", np.unique(y_test))

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import numpy as np


# Definir y entrenar TabNet
clf = TabNetClassifier()

pesos = np.where(
    train_data['Resultado'] == 'V', 3.0,  # Peso para victorias
    np.where(train_data['Resultado'] == 'E', 2.0, 1.0)  # Peso para empates y derrotas
)

clf.fit(
    X_train.values, y_train.values,
    eval_set=[(X_test.values, y_test.values)],
    eval_name=['val'],
    eval_metric=['accuracy', 'logloss'],
    max_epochs=250,
    patience=85,
    weights=pesos,
    batch_size=256,
    virtual_batch_size=128
)

# %%
y_pred = clf.predict(val_data[x_variables].values)  # Get predictions
accuracy = accuracy_score(val_data[y_variables].values, y_pred)  # Calculate accuracy
print(f"Precisión del modelo: {accuracy}")

# %%
probabilidades = clf.predict_proba(val_data[x_variables].values)
clf.classes_

# %%
resultados = []
for probabilidad in  probabilidades:
  lista =[]
  for clase, prob in zip(clf.classes_, probabilidad): # Use probabilidad instead of probabilidades
    #lista.append((clase, prob*100))
    lista.append((clase, round(prob*100,2)))
  lista.sort(key=lambda x: x[1], reverse=True)
  resultados.append(lista)

# %%
all_results = []
for i, row in enumerate(resultados):
    row_results = []
    for formation, prob in row:  # Iterate through tuples in row
        row_results.append((formation, round(prob, 2)))  # Round the probability value
    #row_results.append((verdaderos_v[i], 100))
    row_results.append((val_data['Formación del oponente'].tolist()[i], 100))
    row_results.sort(key=lambda x: x[1], reverse=True)
    all_results.append(row_results)

# Mostrar resultados
for i, row_results in enumerate(all_results):
    print(f"\nResultados para el Partido {i + 1}:")
    for formation, percentage in row_results:
      if percentage == 100:
        print(f"Formacion real del partido: {formation}")
      else:
        formation=formation.replace('vst_','')
        print(f"Formación: {formation}, Probabilidad: {percentage}%")
